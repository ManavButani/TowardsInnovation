# %%
# !pip install yfinance
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import yfinance as yf
import pandas as pd

# %%
# Define the ticker symbol for BTCUSD
ticker_symbol = 'BTC-USD'

# %%
btc_data_from_2019_to_2024_part_1_1_d = yf.download(ticker_symbol, start='2019-01-01', end='2024-10-07', interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
btc_data_from_2019_to_2024_part_1_1_d.index.name = btc_data_from_2019_to_2024_part_1_1_d.index.name.lower()
btc_data_from_2019_to_2024_part_1_1_d.columns = btc_data_from_2019_to_2024_part_1_1_d.columns.str.lower()

# %%
# btc_data_from_2019_to_2024_part_2 = yf.download(ticker_symbol, start='2024-08-10', end='2024-10-10', interval='1d')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# final_till_aug_2024 = pd.concat([btc_data_from_2019_to_2024_part_1, btc_data_from_2019_to_2024_part_2], ignore_index=True)

# %%
# final_till_aug_2024
# Out:
#               Open          High           Low         Close     Adj Close  \
# 0      3746.713379   3850.913818   3707.231201   3843.520020   3843.520020
# 1      3849.216309   3947.981201   3817.409424   3943.409424   3943.409424
# 2      3931.048584   3935.685059   3826.222900   3836.741211   3836.741211
# 3      3832.040039   3865.934570   3783.853760   3857.717529   3857.717529
# 4      3851.973877   3904.903076   3836.900146   3845.194580   3845.194580
# ...            ...           ...           ...           ...           ...
# 2045  56040.632812  57726.882812  54620.507812  55027.460938  55027.460938
# 2046  55030.027344  62673.765625  54766.726562  61710.136719  61710.136719
# 2047  61728.207031  61751.863281  59587.859375  60880.113281  60880.113281
# 2048  60864.062500  61194.777344  60314.175781  60886.492188  60886.492188
# 2049  60864.062500  61194.777344  60314.175781  60823.933594  60823.933594
#
#            Volume
# 0      4324200990
# 1      5244856836
# ...

# %%
btc_data_from_2019_to_2024_part_1_1_d
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-01-01   3746.713379   3850.913818   3707.231201   3843.520020
# 2019-01-02   3849.216309   3947.981201   3817.409424   3943.409424
# 2019-01-03   3931.048584   3935.685059   3826.222900   3836.741211
# 2019-01-04   3832.040039   3865.934570   3783.853760   3857.717529
# 2019-01-05   3851.973877   3904.903076   3836.900146   3845.194580
# ...                  ...           ...           ...           ...
# 2024-08-06  53991.347656  57059.917969  53973.273438  56034.316406
# 2024-08-07  56040.632812  57726.882812  54620.507812  55027.460938
# 2024-08-08  55030.027344  62673.765625  54766.726562  61710.136719
# 2024-08-09  61728.207031  61751.863281  59587.859375  60880.113281
# 2024-08-10  60864.062500  61194.777344  60314.175781  61079.171875
#
#                Adj Close       Volume
# Date
# 2019-01-01   3843.520020   4324200990
# 2019-01-02   3943.409424   5244856836
# ...

# %%
btc_data_from_2019_to_2024_part_1_5_m = yf.download(ticker_symbol, start='2019-01-01', end='2024-10-07', interval='15m')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BTC-USD']: YFChartError('%ticker%: 15m data not available for startTime=1546300800 and endTime=1723282939. The requested range must be within the last 60 days.')

# %%
# open high low close
# 10   15   3    1
# 15   10   1    2

# Pela no open
# Bija no close
# max of high
# min of low

# %%
# highest length candle
# max(all) - min(all)
# highest length candle means the most fluctuation on that period of time.
# shortest length candle means the less fluctuation on that period

# %%
btc_data_from_2019_to_2024_part_1_1_d.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
btc_data_from_2019_to_2024_part_1_1_d.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2024-08-01', '2024-08-02', '2024-08-03', '2024-08-04',
#                '2024-08-05', '2024-08-06', '2024-08-07', '2024-08-08',
#                '2024-08-09', '2024-08-10'],
#               dtype='datetime64[ns]', name='Date', length=2049, freq=None)

# %%
btc_data_from_2019_to_2024_part_1_1_d['year'] = btc_data_from_2019_to_2024_part_1_1_d.index.year
btc_data_from_2019_to_2024_part_1_1_d['month'] = btc_data_from_2019_to_2024_part_1_1_d.index.month
btc_data_from_2019_to_2024_part_1_1_d['day_name'] = btc_data_from_2019_to_2024_part_1_1_d.index.day_name()

# %%
btc_data_from_2019_to_2024_part_1_1_d
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-01-01   3746.713379   3850.913818   3707.231201   3843.520020
# 2019-01-02   3849.216309   3947.981201   3817.409424   3943.409424
# 2019-01-03   3931.048584   3935.685059   3826.222900   3836.741211
# 2019-01-04   3832.040039   3865.934570   3783.853760   3857.717529
# 2019-01-05   3851.973877   3904.903076   3836.900146   3845.194580
# ...                  ...           ...           ...           ...
# 2024-08-06  53991.347656  57059.917969  53973.273438  56034.316406
# 2024-08-07  56040.632812  57726.882812  54620.507812  55027.460938
# 2024-08-08  55030.027344  62673.765625  54766.726562  61710.136719
# 2024-08-09  61728.207031  61751.863281  59587.859375  60880.113281
# 2024-08-10  60864.062500  61194.777344  60314.175781  61079.171875
#
#                Adj Close       Volume  year  month   day_name
# Date
# 2019-01-01   3843.520020   4324200990  2019      1    Tuesday
# ...

# %%
btc_data_from_2019_to_2024_part_1_1_d['max'] = btc_data_from_2019_to_2024_part_1_1_d[['open', 'high', 'low', 'close']].max(axis=1)
btc_data_from_2019_to_2024_part_1_1_d['min'] = btc_data_from_2019_to_2024_part_1_1_d[['open', 'high', 'low', 'close']].min(axis=1)
btc_data_from_2019_to_2024_part_1_1_d['difference'] = btc_data_from_2019_to_2024_part_1_1_d['max'] - btc_data_from_2019_to_2024_part_1_1_d['min']

# %%
btc_data_from_2019_to_2024_part_1_1_d
# Out:
#                     open          high           low         close  \
# date
# 2019-01-01   3746.713379   3850.913818   3707.231201   3843.520020
# 2019-01-02   3849.216309   3947.981201   3817.409424   3943.409424
# 2019-01-03   3931.048584   3935.685059   3826.222900   3836.741211
# 2019-01-04   3832.040039   3865.934570   3783.853760   3857.717529
# 2019-01-05   3851.973877   3904.903076   3836.900146   3845.194580
# ...                  ...           ...           ...           ...
# 2024-08-06  53991.347656  57059.917969  53973.273438  56034.316406
# 2024-08-07  56040.632812  57726.882812  54620.507812  55027.460938
# 2024-08-08  55030.027344  62673.765625  54766.726562  61710.136719
# 2024-08-09  61728.207031  61751.863281  59587.859375  60880.113281
# 2024-08-10  60864.062500  61194.777344  60314.175781  61079.171875
#
#                adj close       volume  year  month   day_name           max  \
# date
# ...

# %%
year_volume_chart = btc_data_from_2019_to_2024_part_1_1_d.groupby(btc_data_from_2019_to_2024_part_1_1_d.year).agg({'volume': 'sum'})

# %%
year_volume_chart
# Out:
#               volume
# year
# 2019   6106628278860
# 2020  12086518388859
# 2021  17211845901724
# 2022  10954842244160
# 2023   6661589630309
# 2024   7127993986036

# %%
month_volume_chart = btc_data_from_2019_to_2024_part_1_1_d.groupby(btc_data_from_2019_to_2024_part_1_1_d.month).agg({'volume': 'sum'})

# %%
month_volume_chart
# Out:
#               volume
# month
# 1      5614573312004
# 2      5855656535883
# 3      6430240501588
# 4      5803698033323
# 5      6410573292169
# 6      4648863547008
# 7      4304535472804
# 8      4043359029040
# 9      4119543644612
# 10     4233486644153
# 11     4618729524766
# 12     4066158892598

# %%
month_volume_chart = month_volume_chart.sort_values(by='volume', ascending=True)

# %%
# Group by the date index and sum the volumes
# df_daily_volume = btc_data_from_2019_to_2024_part_1_1_d.groupby(btc_data_from_2019_to_2024_part_1_1_d.index.date)['volume'].sum()

# %%
month_year_volume_analysis = btc_data_from_2019_to_2024_part_1_1_d.groupby(['month', 'year']).agg({'volume': 'sum'}).reset_index()

# %%
month_year_volume_analysis
# Out:
#     month  year         volume
# 0       1  2019   167335706864
# 1       1  2020   852872174496
# 2       1  2021  2153473433571
# 3       1  2022   923979037681
# 4       1  2023   690994018045
# ..    ...   ...            ...
# 63     12  2019   633790373416
# 64     12  2020  1212259707946
# 65     12  2021   957047184722
# 66     12  2022   541356716034
# 67     12  2023   721704910480
#
# [68 rows x 3 columns]

# %%
month_year_volume_analysis = month_year_volume_analysis.sort_values(by='volume', ascending=True)

# %%
month_year_volume_analysis
# Out:
#     month  year         volume
# 0       1  2019   167335706864
# 6       2  2019   199100675597
# 12      3  2019   297952790260
# 52      9  2023   337637313742
# 40      7  2023   382224489090
# ..    ...   ...            ...
# 14      3  2021  1681184264687
# 20      4  2021  1844481772417
# 26      5  2021  1976593438572
# 2       1  2021  2153473433571
# 8       2  2021  2267152936675
#
# [68 rows x 3 columns]

# %%
# Ignoring period of corona

without_corona_df = btc_data_from_2019_to_2024_part_1_1_d[~btc_data_from_2019_to_2024_part_1_1_d['year'].isin([2020, 2021])]

# %%
month_year_volume_analysis = without_corona_df.groupby(['month', 'year']).agg({'volume': 'sum'}).reset_index()

# %%
# month_year_volume_analysis = month_year_volume_analysis.sort_values(by='volume', ascending=True)

# %%
month_year_volume_analysis
# Out:
#     month  year         volume
# 0       1  2019   167335706864
# 1       1  2022   923979037681
# 2       1  2023   690994018045
# 3       1  2024   825918941347
# 4       2  2019   199100675597
# 5       2  2022   671335993325
# 6       2  2023   723968574897
# 7       2  2024   830721862621
# 8       3  2019   297952790260
# 9       3  2022   830943838435
# 10      3  2023   883299703608
# 11      3  2024  1446417844950
# 12      4  2019   445364556718
# 13      4  2022   830115888649
# 14      4  2023   511540319004
# 15      4  2024  1016068331704
# 16      5  2019   724157870864
# 17      5  2022  1105689315990
# 18      5  2023   443473015479
# 19      5  2024   874291509757
# 20      6  2019   675855385074
# 21      6  2022   923939211678
# 22      6  2023   481734214225
# 23      6  2024   726773965644
# 24      7  2019   676416326705
# 25      7  2022   927582363389
# 26      7  2023   382224489090
# 27      7  2024   953395573307
# 28      8  2019   533984971734
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a line plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=month_year_volume_analysis, 
             x=month_year_volume_analysis['year'].astype(str) + '-' + month_year_volume_analysis['month'].astype(str), 
             y='volume', 
             marker='o')

plt.title('Monthly Volume Analysis')
plt.xlabel('Year-Month')
plt.ylabel('Total Volume')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
# Create a combined 'Year-Month' column for better x-axis labels
month_year_volume_analysis['year_month'] = month_year_volume_analysis['year'].astype(str) + '-' + month_year_volume_analysis['month'].astype(str)

# Line Plot
sns.lineplot(data=month_year_volume_analysis, x='year_month', y='volume', marker='o')
plt.title('Monthly Volume Analysis')
plt.xlabel('Year-Month')
plt.ylabel('Total Volume')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# Bar Plot
plt.figure(figsize=(10, 6))
sns.barplot(data=month_year_volume_analysis, x='year_month', y='volume', color='c')
plt.title('Monthly Volume Analysis')
plt.xlabel('Year-Month')
plt.ylabel('Total Volume')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
custom_palette = {
    2019: 'yellow',
    2024: 'red',
    2022: 'green',
    2023: 'blue'
}

plt.figure(figsize=(12, 6))
sns.barplot(data=month_year_volume_analysis, x='year_month', y='volume', hue='year', palette=custom_palette)
plt.title('Monthly Volume Analysis')
plt.xlabel('Year-Month')
plt.ylabel('Total Volume')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
