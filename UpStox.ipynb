# %%
import urllib.parse
import pandas as pd
import requests

# %%
apiKey = ""
secretKey = ""

# %%
rurl = urllib.parse.quote("https://127.0.0.1:5000/",safe="")

# %%
uri = f"https://api.upstox.com/v2/login/authorization/dialog?response_type=code&client_id={apiKey}&redirect_uri={rurl}"

# %%
uri
# Out:
# 'https://api.upstox.com/v2/login/authorization/dialog?response_type=code&client_id=ed88d248-511e-4d60-93cc-b6e48082085a&redirect_uri=https%3A%2F%2F127.0.0.1%3A5000%2F'

# %%
code = 'bjpkm0'

# %%
import requests

url = "https://api.upstox.com/v2/login/authorization/token"

payload={
    'code':code,
    'client_id':apiKey,
    'client_secret':  secretKey,
    'redirect_uri':'https://127.0.0.1:5000/',
    'grant_type':'authorization_code'

}
headers = {
   'Content-Type': 'application/x-www-form-urlencoded'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"email":"butanikrenil@gmail.com","exchanges":["NSE","NFO","BCD","BFO","BSE","CDS"],"products":["OCO","D","CO","I"],"broker":"UPSTOX","user_id":"2NCHC2","user_name":"BUTANI KRENIL MAGANBHAI","order_types":["MARKET","LIMIT","SL","SL-M"],"user_type":"individual","poa":false,"ddpi":false,"is_active":true,"access_token":"eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiIyTkNIQzIiLCJqdGkiOiI2ODJmZWZmNDg3MzRiOTFhZTk4MTFjNDkiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6ZmFsc2UsImlhdCI6MTc0Nzk3MjA4NCwiaXNzIjoidWRhcGktZ2F0ZXdheS1zZXJ2aWNlIiwiZXhwIjoxNzQ4MDM3NjAwfQ.iuW-DdD5_ajdIyyehEk2ByRPeujwf54oTd_WYTxPynQ","extended_token":null}

# %%
access_token = response.json()['access_token']

# %%
import requests

def make_request(
    method: str,
    url: str,
    headers: dict = None,
    params: dict = None,
    data: dict = None,
    json: dict = None,
    timeout: int = 30
):
    """
    Make an HTTP request using the specified method, URL, and optional headers, params, data, and json payload.

    Args:
        method (str): HTTP method ('GET', 'POST', 'PUT', 'DELETE', etc.)
        url (str): Target URL for the request.
        headers (dict, optional): HTTP headers.
        params (dict, optional): Query string parameters.
        data (dict, optional): Form-encoded data for POST/PUT.
        json (dict, optional): JSON payload for POST/PUT.
        timeout (int, optional): Timeout in seconds (default is 30).

    Returns:
        requests.Response: Response object from the request.
    """
    try:
        response = requests.request(
            method=method.upper(),
            url=url,
            headers=headers,
            params=params,
            data=data,
            json=json,
            timeout=timeout
        )
        response.raise_for_status()  # Raise HTTPError for bad responses (4xx and 5xx)
        return response
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
        return None

# %%
headers = {
    'Authorization': f'Bearer {access_token}',
    'accept': 'application/json'
}

# %%
complete_csv = "https://assets.upstox.com/market-quote/instruments/exchange/complete.csv.gz"

# %%
df = pd.read_csv(complete_csv)

# %%
df.columns
# Out:
# Index(['instrument_key', 'exchange_token', 'tradingsymbol', 'name',
#        'last_price', 'expiry', 'strike', 'tick_size', 'lot_size',
#        'instrument_type', 'option_type', 'exchange'],
#       dtype='object')

# %%
df['instrument_type'].unique()
# Out:
# array(['OPTCUR', 'EQUITY', 'OPTIDX', 'OPTSTK', 'OPTFUT', 'FUTCOM',
#        'FUTCUR', 'OPTIRD', 'INDEX', 'FUTIDX', nan, 'FUTSTK'], dtype=object)

# %%
df_filtered = df[(df['instrument_type'] == 'OPTSTK')]

# %%
df_filtered
# Out:
#        instrument_key  exchange_token       tradingsymbol  \
# 111      NSE_FO|98917           98917  JSWSTEEL25MAY820PE
# 112      NSE_FO|98913           98913  HINDZINC25MAY510CE
# 115      NSE_FO|98915           98915  HINDZINC25MAY520CE
# 116      NSE_FO|98916           98916  JSWSTEEL25MAY820CE
# 118      NSE_FO|98910           98910  HINDZINC25MAY490PE
# ...               ...             ...                 ...
# 102273   NSE_FO|50250           50250    M&MFIN25JUN280CE
# 102290   NSE_FO|50267           50267    M&MFIN25JUN300PE
# 102292   NSE_FO|50266           50266    M&MFIN25JUN300CE
# 102295   NSE_FO|50273           50273    M&MFIN25JUN310PE
# 102296   NSE_FO|50272           50272    M&MFIN25JUN310CE
#
#                           name  last_price      expiry  strike  tick_size  \
# 111          JSW STEEL LIMITED        0.20  2025-05-29   820.0       0.05
# 112     HINDUSTAN ZINC LIMITED        0.30  2025-05-29   510.0       0.05
# ...

# %%
f_and_o_stocks = df_filtered['name'].unique()

# %%
f_and_o_stocks
# Out:
# array(['JSW STEEL LIMITED', 'HINDUSTAN ZINC LIMITED',
#        'VARUN BEVERAGES LIMITED', 'ADANI ENERGY SOLUTION LTD',
#        'COFORGE LIMITED', 'GRANULES INDIA LIMITED', 'SRF LTD',
#        'COLGATE PALMOLIVE LTD.', 'OBEROI REALTY LIMITED',
#        'SBI CARDS & PAY SER LTD', 'ACC LIMITED', 'DABUR INDIA LTD',
#        'ICICI BANK LTD.', 'VEDANTA LIMITED', 'MAX FINANCIAL SERV LTD',
#        'IDFC FIRST BANK LIMITED', 'SBI LIFE INSURANCE CO LTD', 'MRF LTD',
#        'GODREJ PROPERTIES LTD', 'SOLAR INDUSTRIES (I) LTD',
#        'CYIENT LIMITED', 'ADANI GREEN ENERGY LTD', 'STATE BANK OF INDIA',
#        'BALKRISHNA IND. LTD', 'BAJAJ FINSERV LTD.',
#        'DALMIA BHARAT LIMITED', 'VOLTAS LTD', 'AU SMALL FINANCE BANK LTD',
#        'GODREJ CONSUMER PRODUCTS', 'ADANI ENTERPRISES LIMITED',
#        'SUN PHARMACEUTICAL IND L', 'SHREE CEMENT LIMITED',
#        'ORACLE FIN SERV SOFT LTD.', 'LTIMINDTREE LIMITED',
#        'BANK OF BARODA', 'BSE LIMITED', 'INDUSIND BANK LIMITED',
# ...

# %%
df_filtered = df[(df['instrument_type'] == 'EQUITY') & (df['name'].isin(f_and_o_stocks)) & (df['exchange'] == 'NSE_EQ')]

# %%
df_filtered
# Out:
#              instrument_key  exchange_token tradingsymbol  \
# 101     NSE_EQ|INE585B01010           10999        MARUTI
# 184     NSE_EQ|INE139A01034            6364    NATIONALUM
# 856     NSE_EQ|INE522D01027           19061    MANAPPURAM
# 2289    NSE_EQ|INE00R701025            8075     DALBHARAT
# 2966    NSE_EQ|INE917I01010           16669    BAJAJ-AUTO
# ...                     ...             ...           ...
# 99967   NSE_EQ|INE029A01011             526          BPCL
# 100092  NSE_EQ|INE670A01012            3411     TATAELXSI
# 100547  NSE_EQ|INE092A01019            3405      TATACHEM
# 100783  NSE_EQ|INE200M01039           18921           VBL
# 101681  NSE_EQ|INE016A01026             772         DABUR
#
#                              name  last_price expiry  strike  tick_size  \
# 101      MARUTI SUZUKI INDIA LTD.    12445.00    NaN     NaN       1.00
# 184     NATIONAL ALUMINIUM CO LTD      184.95    NaN     NaN       0.01
# ...

# %%
import requests

url = "https://api.upstox.com/v3/historical-candle/NSE_EQ|INE139A01034/minutes/1/2025-05-22/2025-05-22"

payload={}
headers = {
  'Accept': 'application/json'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"status":"success","data":{"candles":[["2025-05-22T15:29:00+05:30",184.91,185.0,184.8,184.91,152589,0],["2025-05-22T15:28:00+05:30",184.86,185.0,184.83,184.95,142488,0],["2025-05-22T15:27:00+05:30",184.95,185.0,184.8,184.86,97749,0],["2025-05-22T15:26:00+05:30",184.9,185.0,184.77,184.95,168481,0],["2025-05-22T15:25:00+05:30",184.8,184.95,184.73,184.86,128677,0],["2025-05-22T15:24:00+05:30",184.78,184.92,184.33,184.8,383444,0],["2025-05-22T15:23:00+05:30",184.85,184.91,184.73,184.81,125645,0],["2025-05-22T15:22:00+05:30",184.78,184.92,184.72,184.87,103646,0],["2025-05-22T15:21:00+05:30",184.77,184.83,184.68,184.77,126489,0],["2025-05-22T15:20:00+05:30",184.86,185.0,184.68,184.77,318677,0],["2025-05-22T15:19:00+05:30",184.94,185.17,184.81,184.84,315683,0],["2025-05-22T15:18:00+05:30",185.0,185.12,184.78,184.91,293275,0],["2025-05-22T15:17:00+05:30",185.22,185.23,184.86,185.01,277201,0],["2025-05-22T15:16:00+05:30",185.15,185.24,185.12,185.22,169412,0],["2025-05-22T15:15:00+05:30",184.
# ...

# %%
response.json().get("data").get("candles")
# Out:
# [['2025-05-22T09:16:00+05:30', 186.96, 188.24, 185.75, 187.64, 2099431, 0],
#  ['2025-05-22T09:15:00+05:30', 190.0, 192.0, 186.35, 186.96, 5748028, 0]]

# %%
import requests

url = "https://api.upstox.com/v3/historical-candle/NSE_EQ|INE139A01034/minutes/5/2025-05-22/2025-05-01"

payload={}
headers = {
  'Accept': 'application/json'
}

response_5m = requests.request("GET", url, headers=headers, data=payload)

print(response_5m.text)
# Out:
# {"status":"error","errors":[{"errorCode":"UDAPI1088","message":"Invalid date","propertyPath":null,"invalidValue":null,"error_code":"UDAPI1088","property_path":null,"invalid_value":null}]}

# %%
response_5m.json().get("data").get("candles")[-1]
# Out:
# ['2025-05-20T09:15:00+05:30', 184.0, 184.01, 182.66, 183.0, 722097, 0]

# %%
import requests

url = "https://api.upstox.com/v3/historical-candle/:instrument_key/minute/5/2025-05-22/2021-05-21"

payload={}
headers = {
  'Accept': 'application/json'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)

# %%
access_token_dhan =  'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJpc3MiOiJkaGFuIiwicGFydG5lcklkIjoiIiwiZXhwIjoxNzQ4MjI5MjkyLCJ0b2tlbkNvbnN1bWVyVHlwZSI6IlNFTEYiLCJ3ZWJob29rVXJsIjoiIiwiZGhhbkNsaWVudElkIjoiMTEwNTM4NDc0NyJ9.UqegdHjMLNNchcS_0b58Qu5wBnAnw9mR5cMhOK7wIhJZMPtrXNmpoN2hNz8ShcPe5FcC1TJcQ-ZWfa73xPWG5Q'

# %%
url =  'https://api.dhan.co/v2/charts/historical'
headers = {'Content-Type': 'application/json','access-token':access_token_dhan
}

data =     {
        "securityId": "1333",
        "exchangeSegment":"NSE_EQ",
        "instrument": "EQUITY",
        "expiryCode": 0,
        "oi": False,
        "fromDate": "2024-01-08",
        "toDate": "202402-08"
    }

# %%
resp = make_request(method="POST",url=url,headers=headers,json=data)
# Out:
# Request failed: 400 Client Error:  for url: https://api.dhan.co/v2/charts/historical
